# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_excel('População_UF_Idade.xlsx')

# %%
df
# Out:
#       UF IDADE   2010   2011   2012   2013   2014   2015   2016   2017  ...  \
# 0     RO     0  26546  26257  26570  26853  27493  28079  27470  27737  ...
# 1     RO     1  26800  26514  26226  26540  26823  27463  28050  27443  ...
# 2     RO     2  27114  26820  26534  26246  26559  26842  27481  28068  ...
# 3     RO     3  27564  27148  26854  26567  26279  26591  26875  27511  ...
# 4     RO     4  28412  27604  27187  26894  26606  26317  26628  26911  ...
# ...   ..   ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 2452  DF    86   1588   1656   1736   1839   1929   2004   2083   2172  ...
# 2453  DF    87   1286   1409   1473   1548   1644   1728   1799   1874  ...
# 2454  DF    88    953   1142   1254   1314   1384   1475   1554   1620  ...
# 2455  DF    89    581    845   1016   1118   1175   1240   1323   1399  ...
# 2456  DF   90+   3323   3194   3327   3595   3914   4237   4572   4934  ...
#
# ...

# %%
pd.set_option('display.max_rows', 2500)
df_agrupado = pd.DataFrame(df.groupby(['UF','IDADE'])[2017].mean())

# %%
df_agrupado
# Out:
#             2017
# UF IDADE
# AC 0       16378
#    1       16429
#    2       17267
#    3       17065
#    4       16711
#    5       17237
#    6       16832
#    7       16606
#    8       17889
#    9       18332
#    10      18241
#    11      18629
#    12      18567
#    13      18305
#    14      18710
#    15      18722
#    16      18595
#    17      18220
#    18      18008
#    19      17703
#    20      17269
#    21      16757
#    22      16256
#    23      15724
#    24      15268
#    25      14933
#    26      14683
#    27      14426
#    28      14158
#    29      13963
#    30      13865
#    31      13823
#    32      13764
#    33      13707
#    34      13567
#    35      13289
#    36      12911
#    37      12542
#    38      12184
#    39      11773
#    40      11309
#    41      10813
#    42      10317
#    43       9799
#    44       9363
#    45       9020
#    46       8749
#    47       8461
#    48       8196
#    49       7892
#    50       7521
# ...

# %%
df_agrupado.columns.values
# Out:
# array([2017], dtype=int64)
